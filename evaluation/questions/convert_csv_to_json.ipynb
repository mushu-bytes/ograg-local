# %%
import pandas as pd

df = pd.read_csv('nascic_questions.csv',
                usecols=['Question ID', 'Stage of Injury', 'Original Question',
                        'Prompt Inserted into LLM', 'LLM Response',
                        'Date of LLM Response Entry', 'Table?'])

df = df.rename(columns={'Prompt Inserted into LLM': "question"})
df.to_json("nascic_questions.json", orient="records", indent=2)
